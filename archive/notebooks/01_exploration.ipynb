# %% [markdown]
# # 01: データ探索
#
# 公式Community Notesデータの基本統計量・分布を確認する。
#
# データ入手元: https://communitynotes.x.com/guide/en/under-the-hood/download-data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.io.load_data import load_notes, load_ratings, load_status_history
